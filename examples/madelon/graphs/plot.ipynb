# %%
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
# Out:
# /Users/avantishrikumar/anaconda/lib/python2.7/site-packages/scipy/special/__init__.py:640: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ufuncs import *
# /Users/avantishrikumar/anaconda/lib/python2.7/site-packages/scipy/linalg/basic.py:17: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._solve_toeplitz import levinson
# /Users/avantishrikumar/anaconda/lib/python2.7/site-packages/scipy/linalg/__init__.py:207: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._decomp_update import *
# /Users/avantishrikumar/anaconda/lib/python2.7/site-packages/scipy/special/_ellip_harm.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   from ._ellip_harm_2 import _ellipsoid, _ellipsoid_norm
# ...

# %%
ig10x, ig10y = np.loadtxt('ig10.txt', delimiter=',', unpack=True)
shap10x, shap10y = np.loadtxt('shap10.txt', delimiter=',', unpack=True)
shap50x, shap50y = np.loadtxt('shap50.txt', delimiter=',', unpack=True)
lime50x, lime50y = np.loadtxt('lime50.txt', delimiter=',', unpack=True)

# %%
font = {'family' : 'normal',
        'size'   : 10}
import matplotlib
reload(matplotlib)
matplotlib.rc('font', **font)


ig10 = sns.scatterplot(ig10y,ig10x,color="green", label='IG - 10 interpolation points')
shap10 = sns.scatterplot(shap10y, shap10x, color="red", label='SHAP 10 samples')
shap50 = sns.scatterplot(shap50y, shap50x,color="purple", label='SHAP 50 samples')

ig10mean_acc = plt.plot([np.median(ig10y), np.median(ig10y)], [0, 15], linestyle=":", color="green") 
ig10mean_time = plt.plot([0, 1], [np.median(ig10x), np.median(ig10x)], linestyle=":", color="green") 
shap10mean_acc = plt.plot([np.median(shap10y), np.median(shap10y)], [0, 15], linestyle=":", color="red") 
shap10mean_time = plt.plot([0, 1], [np.median(shap10x), np.median(shap10x)], linestyle=":", color="red") 
shap50mean_acc = plt.plot([np.median(shap50y), np.median(shap50y)], [0, 15], linestyle=":", color="purple") 
shap50mean_time = plt.plot([0, 1], [np.median(shap50x), np.median(shap50x)], linestyle=":", color="purple") 


plt.legend()

#lime50 = sns.scatterplot(lime50x, lime50y,color="blue")
#lime50mean = plt.plot([0, 15], [lime50ymean, lime50ymean], linestyle="--", color="blue", label='LIME 50 average') 





plt.ylim((0,15))
plt.xlim((0,1))
plt.title("Runtime vs Accuracy")
plt.ylabel("Runtime in seconds")
plt.xlabel("SVM accuracy using 10 most important features")
#plt.legend((ig10, shap10, shap50),
#           ('IG 10 Points', 'SHAP 10 Samples', 'SHAP 50 Samples'), 
#           scatterpoints=1,
#           loc='lower right',
#           ncol=2,
#           fontsize=9
#          )
#plt.savefig("ImpScoringAlgWithMean.png")
plt.show()
