# %%
# %matplotlib inline

# %%
import h5py
import numpy as np
onehot_train = np.array(h5py.File("my_ctcf_data/train_data.hdf5")['X']['sequence'][:,300:700,:])
onehot_test = np.array(h5py.File("my_ctcf_data/valid_data.hdf5")['X']['sequence'][:,300:700,:])
print(onehot_train.shape)
print(onehot_test.shape)
labels_train = np.array(h5py.File("my_ctcf_data/train_data.hdf5")['Y']['output'][:,0], dtype=int)
labels_test = np.array(h5py.File("my_ctcf_data/valid_data.hdf5")['Y']['output'][:,0], dtype=int)
print(labels_train.shape)
print(labels_test.shape)
# Out:
# (17790, 400, 4)
# (14240, 400, 4)
# (17790,)
# (14240,)

# %%
positive_test_label_indices = np.nonzero(labels_test == 1)[0]
print("Positive test label indices", positive_test_label_indices)
print("Positive test label indices shape ", positive_test_label_indices.shape)
# Out:
# ('Positive test label indices', array([    1,     5,    15, ..., 14216, 14220, 14234]))
# ('Positive test label indices shape ', (2093,))

# %%
onehot_data = onehot_test[positive_test_label_indices]
print("One hot data shape: ", onehot_data.shape)
# Out:
# ('One hot data shape: ', (2093, 400, 4))

# %%
scores = np.load("my_ctcf_data/ctcf_importancescores_chr1.npy")
print("Scores shape: ", scores.shape)
hyp_scores = np.load("my_ctcf_data/ctcf_hypimpscores_chr1.npy")
print("Hyp Scores shape: ", hyp_scores.shape)
# Out:
# ('Scores shape: ', (2093, 400, 4))
# ('Hyp Scores shape: ', (2093, 400, 4))

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(scores[0])
viz_sequence.plot_weights(hyp_scores[0])
viz_sequence.plot_weights(onehot_data[0])

# %%
import h5py
import numpy as np
# %matplotlib inline
import modisco
reload(modisco)
import modisco.backend
reload(modisco.backend.theano_backend)
reload(modisco.backend)
import modisco.nearest_neighbors
reload(modisco.nearest_neighbors)
import modisco.affinitymat
reload(modisco.affinitymat.core)
reload(modisco.affinitymat.transformers)
import modisco.tfmodisco_workflow.seqlets_to_patterns
reload(modisco.tfmodisco_workflow.seqlets_to_patterns)
import modisco.tfmodisco_workflow.workflow
reload(modisco.tfmodisco_workflow.workflow)
import modisco.aggregator
reload(modisco.aggregator)
import modisco.cluster
reload(modisco.cluster.core)
reload(modisco.cluster.phenograph.core)
reload(modisco.cluster.phenograph.cluster)
import modisco.core
reload(modisco.core)
import modisco.coordproducers
reload(modisco.coordproducers)
import modisco.metaclusterers
reload(modisco.metaclusterers)

tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow()(
                task_names=["task0"],
                contrib_scores={'task0': scores},
                hypothetical_contribs={'task0': hyp_scores},
                one_hot=onehot_data)
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled, cuDNN not available)
# On task task0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Done 0
# Got 19275 coords
# Computing thresholds
# Bandwidth calculated: 0.169446468353
# Computed threshold 1.15649551451
# 7141 coords remaining after thresholding
# After resolving overlaps, got 7141 seqlets
# 2 activity patterns with support >= 200 out of 3 possible patterns
# Metacluster sizes:  [3918, 3223]
# Idx to activities:  {0: '-1', 1: '1'}
# On metacluster 1
# Metacluster size 3223
# Relevant tasks:  ('task0',)
# Relevant signs:  (1,)
# (Round 1) num seqlets: 3223
# (Round 1) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 5.85 s
# Starting affinity matrix computations
# Normalization computed in 0.71 s
# Cosine similarity mat computed in 2.58 s
# Normalization computed in 0.71 s
# Cosine similarity mat computed in 2.54 s
# Finished affinity matrix computations in 5.13 s
# (Round 1) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.3 s
# (Round 1) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 12.3 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 12.47 s
# (Round 1) Computed affinity matrix on nearest neighbors in 27.23 s
# Filtered down to 1717 of 3223
# (Round 1) Retained 1717 rows out of 3223 after filtering
# (Round 1) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1717 samples in 0.002s...
# [t-SNE] Computed neighbors for 1717 samples in 0.028s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1717
# [t-SNE] Computed conditional probabilities for sample 1717 / 1717
# [t-SNE] Mean sigma: 0.268154
# (Round 1) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0840151309967 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 200 out of 200 | elapsed:    0.8s finished
# Louvain completed 200 runs in 3.46894097328 seconds
# Wrote graph to binary file in 0.739778995514 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.704525
# After 2 runs, maximum modularity is Q = 0.70861
# After 8 runs, maximum modularity is Q = 0.709483
# Louvain completed 58 runs in 4.50309300423 seconds
# Preproc + Louvain took 8.98318195343 s
# Got 8 clusters after round 1
# Counts:
# {0: 357, 1: 317, 2: 297, 3: 242, 4: 211, 5: 136, 6: 115, 7: 42}
# (Round 1) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 357 seqlets
# Trimmed 19 out of 357
# Skipped 8 seqlets
# Aggregating for cluster 1 with 317 seqlets
# Trimmed 36 out of 317
# Skipped 16 seqlets
# Aggregating for cluster 2 with 297 seqlets
# Trimmed 18 out of 297
# Skipped 22 seqlets
# Aggregating for cluster 3 with 242 seqlets
# Trimmed 6 out of 242
# Skipped 8 seqlets
# Aggregating for cluster 4 with 211 seqlets
# Trimmed 20 out of 211
# Skipped 15 seqlets
# Aggregating for cluster 5 with 136 seqlets
# Trimmed 1 out of 136
# Skipped 15 seqlets
# Aggregating for cluster 6 with 115 seqlets
# Trimmed 3 out of 115
# Skipped 11 seqlets
# Aggregating for cluster 7 with 42 seqlets
# Trimmed 13 out of 42
# Skipped 1 seqlets
# (Round 2) num seqlets: 1503
# (Round 2) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 3.06 s
# Starting affinity matrix computations
# Normalization computed in 0.36 s
# Cosine similarity mat computed in 1.36 s
# Normalization computed in 0.35 s
# Cosine similarity mat computed in 1.23 s
# Finished affinity matrix computations in 2.6 s
# (Round 2) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.09 s
# (Round 2) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 9.02 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 9.93 s
# (Round 2) Computed affinity matrix on nearest neighbors in 20.24 s
# Not applying filtering for rounds above first round
# (Round 2) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1503 samples in 0.001s...
# [t-SNE] Computed neighbors for 1503 samples in 0.034s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1503
# [t-SNE] Computed conditional probabilities for sample 1503 / 1503
# [t-SNE] Mean sigma: 0.257043
# (Round 2) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.064414024353 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 200 out of 200 | elapsed:    0.8s finished
# Louvain completed 200 runs in 2.84597802162 seconds
# Wrote graph to binary file in 0.528053998947 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.707845
# After 17 runs, maximum modularity is Q = 0.716187
# Louvain completed 67 runs in 3.9789659977 seconds
# Preproc + Louvain took 7.57547688484 s
# Got 7 clusters after round 2
# Counts:
# {0: 347, 1: 336, 2: 276, 3: 219, 4: 144, 5: 109, 6: 72}
# (Round 2) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 347 seqlets
# Trimmed 76 out of 347
# Skipped 1 seqlets
# Aggregating for cluster 1 with 336 seqlets
# Trimmed 51 out of 336
# Skipped 1 seqlets
# Aggregating for cluster 2 with 276 seqlets
# Trimmed 19 out of 276
# Skipped 4 seqlets
# Aggregating for cluster 3 with 219 seqlets
# Trimmed 30 out of 219
# Aggregating for cluster 4 with 144 seqlets
# Trimmed 27 out of 144
# Aggregating for cluster 5 with 109 seqlets
# Trimmed 17 out of 109
# Aggregating for cluster 6 with 72 seqlets
# Trimmed 16 out of 72
# Got 7 clusters
# Splitting into subclusters...
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0626201629639 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00385171
# After 2 runs, maximum modularity is Q = 0.00385951
# Louvain completed 22 runs in 0.813857078552 seconds
# Similarity is 0.822869; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0652008056641 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00675559
# After 7 runs, maximum modularity is Q = 0.00675583
# Louvain completed 27 runs in 0.889497041702 seconds
# Similarity is 0.99308; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0579040050507 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00896551
# Louvain completed 21 runs in 0.636017799377 seconds
# Similarity is 0.618284; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0252439975739 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00488636
# After 2 runs, maximum modularity is Q = 0.00488637
# After 4 runs, maximum modularity is Q = 0.00540283
# After 8 runs, maximum modularity is Q = 0.00540284
# Louvain completed 28 runs in 0.816386938095 seconds
# Similarity is 0.76917; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00565505027771 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00524664
# Louvain completed 21 runs in 0.532294034958 seconds
# Similarity is 0.837637; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00613903999329 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = -0.0115548
# After 2 runs, maximum modularity is Q = -0.00991979
# After 3 runs, maximum modularity is Q = -0.00321164
# After 4 runs, maximum modularity is Q = 0.00739369
# After 6 runs, maximum modularity is Q = 0.0073937
# Louvain completed 26 runs in 0.740540027618 seconds
# Similarity is 0.733305; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00304412841797 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0072417
# Louvain completed 21 runs in 0.524981975555 seconds
# Similarity is 0.742089; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0143580436707 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00787181
# Louvain completed 21 runs in 0.560464859009 seconds
# Similarity is 0.921469; is_dissimilar is False
# Got 5 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.03040599823 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00678746
# After 3 runs, maximum modularity is Q = 0.00678832
# After 4 runs, maximum modularity is Q = 0.00679168
# Louvain completed 24 runs in 0.690008163452 seconds
# Similarity is 0.977919; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0121011734009 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00621271
# Louvain completed 21 runs in 0.542106151581 seconds
# Similarity is 0.909796; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0131680965424 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00546515
# Louvain completed 21 runs in 0.538214921951 seconds
# Similarity is 0.962292; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00470495223999 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00627127
# Louvain completed 21 runs in 0.526836872101 seconds
# Similarity is 0.965084; is_dissimilar is False
# Merging on 11 clusters
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 11 patterns after merging
# Performing seqlet reassignment
# Cross contin jaccard time taken: 0.48 s
# Cross contin jaccard time taken: 0.48 s
# Discarded 16 seqlets
# Skipped 1 seqlets
# Skipped 3 seqlets
# Skipped 2 seqlets
# Skipped 1 seqlets
# Got 8 patterns after reassignment
# Total time taken is 116.2s
# On metacluster 0
# Metacluster size 3918
# Relevant tasks:  ('task0',)
# Relevant signs:  (-1,)
# (Round 1) num seqlets: 3918
# (Round 1) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 7.19 s
# Starting affinity matrix computations
# Normalization computed in 0.88 s
# Cosine similarity mat computed in 3.3 s
# Normalization computed in 0.89 s
# Cosine similarity mat computed in 3.09 s
# Finished affinity matrix computations in 6.4 s
# (Round 1) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.38 s
# (Round 1) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 15.94 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 16.3 s
# (Round 1) Computed affinity matrix on nearest neighbors in 35.27 s
# Filtered down to 1807 of 3918
# (Round 1) Retained 1807 rows out of 3918 after filtering
# (Round 1) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1807 samples in 0.002s...
# [t-SNE] Computed neighbors for 1807 samples in 0.030s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1807
# [t-SNE] Computed conditional probabilities for sample 1807 / 1807
# [t-SNE] Mean sigma: 0.256041
# (Round 1) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0781769752502 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 200 out of 200 | elapsed:    1.0s finished
# Louvain completed 200 runs in 3.92059111595 seconds
# Wrote graph to binary file in 0.814189195633 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.750488
# After 6 runs, maximum modularity is Q = 0.750495
# After 18 runs, maximum modularity is Q = 0.751189
# Louvain completed 68 runs in 5.52915406227 seconds
# Preproc + Louvain took 10.5597679615 s
# Got 8 clusters after round 1
# Counts:
# {0: 366, 1: 330, 2: 327, 3: 257, 4: 255, 5: 230, 6: 25, 7: 17}
# (Round 1) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 366 seqlets
# Trimmed 22 out of 366
# Skipped 27 seqlets
# Aggregating for cluster 1 with 330 seqlets
# Trimmed 118 out of 330
# Skipped 11 seqlets
# Aggregating for cluster 2 with 327 seqlets
# Trimmed 31 out of 327
# Skipped 52 seqlets
# Aggregating for cluster 3 with 257 seqlets
# Trimmed 19 out of 257
# Skipped 31 seqlets
# Aggregating for cluster 4 with 255 seqlets
# Trimmed 9 out of 255
# Skipped 29 seqlets
# Aggregating for cluster 5 with 230 seqlets
# Trimmed 29 out of 230
# Skipped 22 seqlets
# Aggregating for cluster 6 with 25 seqlets
# Trimmed 0 out of 25
# Skipped 2 seqlets
# Aggregating for cluster 7 with 17 seqlets
# Trimmed 0 out of 17
# Skipped 6 seqlets
# (Round 2) num seqlets: 1399
# (Round 2) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 2.79 s
# Starting affinity matrix computations
# Normalization computed in 0.34 s
# Cosine similarity mat computed in 1.14 s
# Normalization computed in 0.32 s
# Cosine similarity mat computed in 1.11 s
# Finished affinity matrix computations in 2.25 s
# (Round 2) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.1 s
# (Round 2) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 9.42 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 8.96 s
# (Round 2) Computed affinity matrix on nearest neighbors in 19.6 s
# Not applying filtering for rounds above first round
# (Round 2) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1399 samples in 0.001s...
# [t-SNE] Computed neighbors for 1399 samples in 0.023s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1399
# [t-SNE] Computed conditional probabilities for sample 1399 / 1399
# [t-SNE] Mean sigma: 0.251467
# (Round 2) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0597138404846 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 200 out of 200 | elapsed:    0.9s finished
# Louvain completed 200 runs in 2.84492492676 seconds
# Wrote graph to binary file in 0.50107216835 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.698992
# After 4 runs, maximum modularity is Q = 0.703856
# After 24 runs, maximum modularity is Q = 0.70552
# Louvain completed 74 runs in 4.89653086662 seconds
# Preproc + Louvain took 8.43997001648 s
# Got 8 clusters after round 2
# Counts:
# {0: 363, 1: 238, 2: 206, 3: 182, 4: 181, 5: 154, 6: 58, 7: 17}
# (Round 2) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 363 seqlets
# Trimmed 104 out of 363
# Aggregating for cluster 1 with 238 seqlets
# Trimmed 65 out of 238
# Skipped 9 seqlets
# Aggregating for cluster 2 with 206 seqlets
# Trimmed 67 out of 206
# Aggregating for cluster 3 with 182 seqlets
# Trimmed 54 out of 182
# Aggregating for cluster 4 with 181 seqlets
# Trimmed 34 out of 181
# Skipped 3 seqlets
# Aggregating for cluster 5 with 154 seqlets
# Trimmed 26 out of 154
# Aggregating for cluster 6 with 58 seqlets
# Trimmed 2 out of 58
# Skipped 3 seqlets
# Aggregating for cluster 7 with 17 seqlets
# Trimmed 10 out of 17
# Got 8 clusters
# Splitting into subclusters...
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0588071346283 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00516476
# After 2 runs, maximum modularity is Q = 0.00517956
# After 4 runs, maximum modularity is Q = 0.00521291
# Louvain completed 24 runs in 0.970400094986 seconds
# Similarity is 0.81873; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0234899520874 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00492905
# After 3 runs, maximum modularity is Q = 0.00521584
# Louvain completed 23 runs in 0.80156493187 seconds
# Similarity is 0.820182; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0152940750122 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0039828
# After 7 runs, maximum modularity is Q = 0.00403568
# Louvain completed 27 runs in 0.894991874695 seconds
# Similarity is 0.848943; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0148241519928 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00434585
# After 2 runs, maximum modularity is Q = 0.00444287
# Louvain completed 22 runs in 0.727877140045 seconds
# Similarity is 0.824412; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0167701244354 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00699228
# After 2 runs, maximum modularity is Q = 0.00700138
# After 5 runs, maximum modularity is Q = 0.00700387
# Louvain completed 25 runs in 0.786750078201 seconds
# Similarity is 0.878682; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0128209590912 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0040218
# After 2 runs, maximum modularity is Q = 0.00419468
# After 3 runs, maximum modularity is Q = 0.0042327
# After 7 runs, maximum modularity is Q = 0.00426036
# After 9 runs, maximum modularity is Q = 0.00428794
# After 13 runs, maximum modularity is Q = 0.00431293
# After 14 runs, maximum modularity is Q = 0.0044815
# Louvain completed 34 runs in 1.15650296211 seconds
# Similarity is 0.73004; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00425004959106 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00352335
# After 2 runs, maximum modularity is Q = 0.00400493
# After 3 runs, maximum modularity is Q = 0.0040817
# After 4 runs, maximum modularity is Q = 0.00417173
# After 7 runs, maximum modularity is Q = 0.00419149
# After 12 runs, maximum modularity is Q = 0.00421543
# Louvain completed 32 runs in 1.03179812431 seconds
# Similarity is 0.709698; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0054190158844 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00467625
# After 2 runs, maximum modularity is Q = 0.00478091
# Louvain completed 22 runs in 0.665065050125 seconds
# Similarity is 0.764672; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00196313858032 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00435168
# After 2 runs, maximum modularity is Q = 0.00445973
# After 3 runs, maximum modularity is Q = 0.00469675
# After 7 runs, maximum modularity is Q = 0.0047272
# After 10 runs, maximum modularity is Q = 0.00496285
# Louvain completed 30 runs in 0.959093093872 seconds
# Similarity is 0.568025; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00477004051208 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00391407
# After 2 runs, maximum modularity is Q = 0.00419288
# After 5 runs, maximum modularity is Q = 0.00421974
# After 6 runs, maximum modularity is Q = 0.00440821
# After 10 runs, maximum modularity is Q = 0.00440822
# Louvain completed 30 runs in 0.968459129333 seconds
# Similarity is 0.722883; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00256013870239 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00553538
# After 5 runs, maximum modularity is Q = 0.00555875
# Louvain completed 25 runs in 0.759127140045 seconds
# Similarity is 0.662647; is_dissimilar is True
# Got 4 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00501990318298 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = -0.0100701
# After 2 runs, maximum modularity is Q = 0.00607847
# Louvain completed 22 runs in 0.671816110611 seconds
# Similarity is 0.622119; is_dissimilar is True
# Got 2 subclusters
# Merging on 12 clusters
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Collapsing 3 & 4 with prob 1.45305275696e-05 and sim 0.93541454152
# Collapsing 7 & 8 with prob 0.00014065200553 and sim 0.885235546795
# Trimmed 30 out of 272
# Trimmed 22 out of 90
# On merging iteration 2
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 10 patterns after merging
# Performing seqlet reassignment
# Cross contin jaccard time taken: 0.59 s
# Cross contin jaccard time taken: 0.6 s
# Discarded 82 seqlets
# Skipped 9 seqlets
# Got 5 patterns after reassignment
# Total time taken is 136.35s

# %%
import h5py
import modisco.util
reload(modisco.util)
# !rm task0_results.hdf5
grp = h5py.File("task0_results.hdf5")
tfmodisco_results.save_hdf5(grp)

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

import sklearn.decomposition
import sklearn.manifold

hdf5_results = h5py.File("task0_results.hdf5")

#patterns = (tfmodisco_results
#            .metacluster_idx_to_submetacluster_results[0]
#            .seqlets_to_patterns_result.patterns);
patterns = (list(hdf5_results
                 ["metacluster_idx_to_submetacluster_results"]
                 ["metacluster0"]
                 ["seqlets_to_patterns_result"]
                 ["patterns"]["all_pattern_names"]))
print(len(patterns))
pattern_grp = (hdf5_results
                 ["metacluster_idx_to_submetacluster_results"]
                 ["metacluster0"]
                 ["seqlets_to_patterns_result"]
                 ["patterns"])

for pattern_name in patterns:
    pattern = pattern_grp[pattern_name]
    print(pattern_name)
    print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
    #pattern.plot_counts(counts=aggregated_seqlet.get_per_position_seqlet_center_counts())
    background = np.array([0.27, 0.23, 0.23, 0.27])
    print("fwd:")
    viz_sequence.plot_weights(pattern["task0_contrib_scores"]["fwd"])
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                    background=background))

    print("reverse:")
    viz_sequence.plot_weights(pattern["task0_contrib_scores"]["rev"])
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["rev"]),
                                                    background=background))
# Out:
# 5
# pattern_0
# ('total seqlets:', 259)
# fwd:
# reverse:
# pattern_1
# ('total seqlets:', 235)
# fwd:
# reverse:
# pattern_2
# ('total seqlets:', 164)
# fwd:
# reverse:
# pattern_3
# ('total seqlets:', 140)
# fwd:
# reverse:
# pattern_4
# ('total seqlets:', 80)
# fwd:
# reverse:

# %%
pattern.keys()
